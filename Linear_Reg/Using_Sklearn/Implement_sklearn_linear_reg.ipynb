# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("homeprices.csv")
data.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.scatter(data.area,data.price)
plt.xlabel("Area")
plt.ylabel("Price($)")
plt.title("Raw Data")
# Out:
# Text(0.5, 1.0, 'Raw Data')

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['area']],data.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5500]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([927448.63013699])

# %%
c = reg.intercept_
m = reg.coef_
print(f"c = {c} and m = {m}")
# Out:
# c = 180616.43835616432 and m = [135.78767123]

# %%
# Input your Value to predict it
#x = int(input())
#print(f"$ {m * x + c}")

# %%
# %matplotlib inline
plt.scatter(data.area,data.price, c = 'r', marker='x')
plt.xlabel("Area")
plt.ylabel("Price($)")
plt.title("Projected Model")
plt.plot(data.area,reg.predict(data[['area']]) )

# %%
d = pd.read_csv("areas.csv")

# %%
z = reg.predict(d)

# %%
d['predicted_prices'] = z
d['predicted_prices'] = d['predicted_prices'].round(2)
d
# Out:
#     area  predicted_prices
# 0   1000         316404.11
# 1   1500         384297.95
# 2   2300         492928.08
# 3   3540         661304.79
# 4   4120         740061.64
# 5   4560         799808.22
# 6   5490         926090.75
# 7   3460         650441.78
# 8   4750         825607.88
# 9   2300         492928.08
# 10  9000        1402705.48
# 11  8600        1348390.41
# 12  7100        1144708.90

# %%
d.to_csv("Predicted_Prices.csv")

# %%
# %matplotlib inline
plt.scatter(d.area,d.predicted_prices, c= 'r', marker= 'x')
#plt.plot(d.area,d.predicted_prices)
plt.xlabel("Area")
plt.ylabel("Price($)")
plt.title("Predicted Prices")
# Out:
# Text(0.5, 1.0, 'Predicted Prices')
